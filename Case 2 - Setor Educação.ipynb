# %%
# importando as librarys

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# lendo as base de dados

base_dados = pd.read_csv('StudentsPerformance+(1).csv')
base_dados.head(5)

# dimensões

print('Linhas: {}, Colunas: {}'.format(base_dados.shape[0], base_dados.shape[1]))
# Out:
# Linhas: 1000, Colunas: 8

# %%
# registros iniciais

base_dados.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# campos nulos

campos_nulos = base_dados.isnull()

plt.figure(figsize= (20,10))
sns.heatmap(campos_nulos, cbar=False)

campos_nulos.sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# informações da base de dados
base_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# valores unicos

base_dados.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
# valores duplicados

base_dados.duplicated().sum()
# Out:
# 0

# %%
# estatisticas

base_dados.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# segmentando por genero

print(base_dados['gender'].value_counts())
print(base_dados['gender'].value_counts(normalize= True)*100)
# Out:
# female    518
# male      482
# Name: gender, dtype: int64
# female    51.8
# male      48.2
# Name: gender, dtype: float64

# %%
# segmentando por etnia

print(base_dados['race/ethnicity'].value_counts())
print(base_dados['race/ethnicity'].value_counts(normalize= True)*100)
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: race/ethnicity, dtype: float64

# %%
# segmentando por educacional dos pais

print(base_dados['parental level of education'].value_counts())
print(base_dados['parental level of education'].value_counts(normalize= True)*100)
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: parental level of education, dtype: float64

# %%
# segmentando por opção de lanche ( normal ou reduzido/gratuito )

print(base_dados['lunch'].value_counts())
print(base_dados['lunch'].value_counts(normalize= True)*100)
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64
# standard        64.5
# free/reduced    35.5
# Name: lunch, dtype: float64

# %%
# segmentando por alunos que fizeram curso preparatorio

print(base_dados['test preparation course'].value_counts())
print(base_dados['test preparation course'].value_counts(normalize= True)*100)
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64
# none         64.2
# completed    35.8
# Name: test preparation course, dtype: float64

# %%
# analise do teste de matematica por sexo

plt.figure(figsize= (20,10))
sns.boxplot(data= base_dados, x='math score', y='gender');

# %%
# analise do teste de leitura por sexo

plt.figure(figsize= (20,10))
sns.boxplot(data= base_dados, x='reading score', y='gender');

# %%
# analise do teste de escrita por sexo

plt.figure(figsize= (20,10))
sns.boxplot(data= base_dados, x='writing score', y='gender');

# %%
base_dados.groupby(by= ['gender']).describe()['math score'].reset_index()


# outlier da base feminina acabou puxando demais a média.
# mas verificando pelos quartis ainda sim ficaria abaixo da média masculina
# obs: no teste de matematica
# Out:
#    gender  count       mean        std   min   25%   50%   75%    max
# 0  female  518.0  63.633205  15.491453   0.0  54.0  65.0  74.0  100.0
# 1    male  482.0  68.728216  14.356277  27.0  59.0  69.0  79.0  100.0

# %%
# analise grafica por etinia pairplot

plt.figure(figsize= (20,10))
sns.pairplot(base_dados, hue='race/ethnicity')

# %%
# analise gráfica por etnia boxplot

plt.figure(figsize= (20,15))
sns.boxplot(data= base_dados, x= 'math score', y='race/ethnicity');

# %%
# analise gráfica por educacional dos pais boxplot

plt.figure(figsize= (20,15))
sns.boxplot(data= base_dados, x= 'math score', y='parental level of education');

# %%
base_dados.groupby(by= ['parental level of education']).describe()['math score'].reset_index()

# os filhos que tem pais apenas com ensino medio, tiveram a menor média em matematica
# em consequencia os pais que possuem mestrado, seus filho tiveram uma media.
# obsevação é que todos estão na casa de 60-70 de media
# os outliers são aparentes para o menor nivel educacional
# Out:
#   parental level of education  count       mean        std   min    25%   50%  \
# 0          associate's degree  222.0  67.882883  15.112093  26.0  57.00  67.0
# 1           bachelor's degree  118.0  69.389831  14.943789  29.0  61.00  68.0
# 2                 high school  196.0  62.137755  14.539651   8.0  53.75  63.0
# 3             master's degree   59.0  69.745763  15.153915  40.0  55.50  73.0
# 4                some college  226.0  67.128319  14.312897  19.0  59.00  67.5
# 5            some high school  179.0  63.497207  15.927989   0.0  53.00  65.0
#
#     75%    max
# 0  80.0  100.0
# 1  79.0  100.0
# 2  72.0   99.0
# 3  81.0   95.0
# 4  76.0  100.0
# 5  74.0   97.0

# %%
# analise grafica de quem fez o teste preparatorio ou nao

plt.figure(figsize= (20,15))
sns.boxplot(data= base_dados, x='math score',
            y= 'test preparation course');

# %%
base_dados.groupby(by= ['test preparation course']).describe()['math score'].reset_index()

# na media quem fez o curso se saiu melhor
# a variação foi de +-5 pts
# os outliers minimos de quem nao fez foram maiores e aparentes.
# Out:
#   test preparation course  count       mean        std   min   25%   50%  \
# 0               completed  358.0  69.695531  14.444699  23.0  60.0  69.0
# 1                    none  642.0  64.077882  15.192376   0.0  54.0  64.0
#
#      75%    max
# 0  79.00  100.0
# 1  74.75  100.0

# %%
plt.figure(figsize= (20,15))
sns.scatterplot(data= base_dados, x= 'math score', y= 'writing score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='writing score'>
